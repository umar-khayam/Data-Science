# %%
import pandas as pd

# %%
dognition_data_aggregated_by_dogid = pd.read_excel('dognition_data_aggregated_by_dogid.xlsx')
dognition_data_aggregated_by_dogid.columns
# Out:
# Index(['Dog ID', 'Total Tests Completed', 'Mean ITI (days)',
#        'Mean ITI (minutes)', 'Median ITI (days)', 'Median ITI (minutes)',
#        'Time diff between first and last game (days)',
#        'Time diff between first and last game (minutes)', 'User ID', 'Gender',
#        'Birthday', 'Breed', 'Breed_Type', 'Breed_Group', 'Weight', 'Dog_Fixed',
#        'DNA_Tested', 'Dimension', 'Sign_in_Count', 'Max_Dogs', 'Membership_ID',
#        'Subscribed', 'City', 'State', 'Zip', 'Country', 'Exclude',
#        'Free_Start_User', 'Last_Active_At', 'Membership_Type'],
#       dtype='object')

# %%
dognition_data_aggregated_by_dogid['Max_Dogs'].unique()
# Out:
# array([ 2.,  1., 13.,  4.,  3.,  7.,  6., 20., 12., 36.,  5.,  8., 10.,
#        15.,  0., nan])

# %%
dognition_data_aggregated_by_dogid[dognition_data_aggregated_by_dogid['Dimension']=='socialite'].count()
# Out:
# Dog ID                                             871
# Total Tests Completed                              871
# Mean ITI (days)                                    871
# Mean ITI (minutes)                                 871
# Median ITI (days)                                  871
# Median ITI (minutes)                               871
# Time diff between first and last game (days)       871
# Time diff between first and last game (minutes)    871
# User ID                                            871
# Gender                                             871
# Birthday                                           871
# Breed                                              870
# Breed_Type                                         871
# Breed_Group                                        871
# Weight                                             871
# Dog_Fixed                                          871
# DNA_Tested                                         871
# ...

# %%
dognition_data_aggregated_by_dogid.shape
# Out:
# (17986, 30)

# %%
dognition_data_no_aggregation_with_zip_code_correction = pd.read_excel('dognition_data_no_aggregation_with_zip_code_correction.xlsx')
dognition_data_no_aggregation_with_zip_code_correction.columns
# Out:
# Index(['Created_at', 'Updated_at', 'User_ID', 'Dog_ID', 'Test_name',
#        'Subcategory_name', 'Gender', 'Birthday', 'Breed', 'Breed_Type',
#        'Breed_Group', 'Weight', 'Dog_Fixed', 'DNA_Tested', 'Dimension',
#        'Sign_in_Count', 'Max_Dogs', 'Membership_ID', 'Subscribed', 'City',
#        'State', 'Zip', 'Country', 'Exclude', 'Free_Start_User',
#        'Last_Active_At', 'Membership_Type', 'Rating', 'Rank_by_UserID',
#        'Rank_by_DogID'],
#       dtype='object')

# %%
dognition_data_no_aggregation = pd.read_excel('dognition_data_no_aggregation.xlsx')
dognition_data_no_aggregation.columns
# Out:
# Index(['Created_at', 'Updated_at', 'User_ID', 'Dog_ID', 'Test_name',
#        'Subcategory_name', 'Gender', 'Birthday', 'Breed', 'Breed_Type',
#        'Breed_Group', 'Weight', 'Dog_Fixed', 'DNA_Tested', 'Dimension',
#        'Sign_in_Count', 'Max_Dogs', 'Membership_ID', 'Subscribed', 'City',
#        'State', 'Zip', 'Country', 'Exclude', 'Free_Start_User',
#        'Last_Active_At', 'Membership_Type', 'Rating', 'Rank_by_UserID',
#        'Rank_by_DogID'],
#       dtype='object')

# %%
print(dognition_data_aggregated_by_dogid.shape)
dognition_data_aggregated_by_dogid.head()
# Out:
# (17986, 30)
#                                  Dog ID  Total Tests Completed  \
# 0  fd27b272-7144-11e5-ba71-058fbc01cf0b                     21
# 1  fd27b5ba-7144-11e5-ba71-058fbc01cf0b                     20
# 2  fd27b6b4-7144-11e5-ba71-058fbc01cf0b                      2
# 3  fd27b79a-7144-11e5-ba71-058fbc01cf0b                     11
# 4  fd27b86c-7144-11e5-ba71-058fbc01cf0b                     31
#
#    Mean ITI (days)  Mean ITI (minutes)  Median ITI (days)  \
# 0        28.201076        40609.549167           0.004687
# 1         0.413307          595.162281           0.005845
# 2         0.009132           13.150000           0.009132
# 3        56.115179        80805.858333           0.004433
# 4         7.734254        11137.326111           0.000399
#
#    Median ITI (minutes)  Time diff between first and last game (days)  \
# 0              6.750000                                    564.021516
# 1              8.416667                                      7.852836
# ...

# %%
print(dognition_data_no_aggregation_with_zip_code_correction.shape)
dognition_data_no_aggregation_with_zip_code_correction.head()
# Out:
# (177481, 30)
#            Created_at          Updated_at  \
# 0 2013-05-13 16:17:00 2013-05-13 16:17:00
# 1 2013-05-22 18:54:00 2013-05-22 18:54:00
# 2 2013-05-22 18:55:00 2013-05-22 18:55:00
# 3 2013-05-22 18:56:00 2013-05-22 18:56:00
# 4 2013-05-22 18:58:00 2013-05-22 18:58:00
#
#                                 User_ID                                Dog_ID  \
# 0  ce134a78-7144-11e5-ba71-058fbc01cf0b  fd3d1b44-7144-11e5-ba71-058fbc01cf0b
# 1  ce134a78-7144-11e5-ba71-058fbc01cf0b  fd3d1b44-7144-11e5-ba71-058fbc01cf0b
# 2  ce134a78-7144-11e5-ba71-058fbc01cf0b  fd3d1b44-7144-11e5-ba71-058fbc01cf0b
# 3  ce134a78-7144-11e5-ba71-058fbc01cf0b  fd3d1b44-7144-11e5-ba71-058fbc01cf0b
# 4  ce134a78-7144-11e5-ba71-058fbc01cf0b  fd3d1b44-7144-11e5-ba71-058fbc01cf0b
#
#              Test_name Subcategory_name Gender  Birthday     Breed  \
# 0         Yawn Warm-up          Empathy   male      2009  Shih Tzu
# 1            Yawn Game          Empathy   male      2009  Shih Tzu
# ...

# %%
print(dognition_data_no_aggregation.shape)
dognition_data_no_aggregation.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(dognition_data_no_aggregation.shape)
#       2 dognition_data_no_aggregation.head()
#
# NameError: name 'dognition_data_no_aggregation' is not defined

# %%
dognition_data_no_aggregation['Subcategory_name'].nunique()
# Out:
# 16

# %%
dognition_data_no_aggregation[dognition_data_no_aggregation['Dog_ID']=='fd3d1b44-7144-11e5-ba71-058fbc01cf0b']
# Out:
#             Created_at          Updated_at  \
# 0  2013-05-13 16:17:00 2013-05-13 16:17:00
# 1  2013-05-22 18:54:00 2013-05-22 18:54:00
# 2  2013-05-22 18:55:00 2013-05-22 18:55:00
# 3  2013-05-22 18:56:00 2013-05-22 18:56:00
# 4  2013-05-22 18:58:00 2013-05-22 18:58:00
# 5  2013-05-22 18:59:00 2013-05-22 18:59:00
# 6  2013-05-22 19:00:00 2013-05-22 19:00:00
# 7  2013-05-22 19:02:00 2013-05-22 19:02:00
# 8  2013-05-22 19:02:00 2013-05-22 19:02:00
# 9  2013-05-22 19:02:00 2013-05-22 19:02:00
# 10 2013-05-22 19:02:00 2013-05-22 19:02:00
# 11 2013-05-22 19:06:00 2013-05-22 19:06:00
# 12 2013-05-22 19:07:00 2013-05-22 19:07:00
# 13 2013-05-22 19:08:00 2013-05-22 19:08:00
# 14 2013-05-22 19:08:00 2013-05-22 19:08:00
# 15 2013-05-22 19:36:00 2013-05-22 19:36:00
# 16 2013-07-10 17:33:00 2013-07-10 17:33:00
# 17 2013-07-10 17:33:00 2013-07-10 17:33:00
# 18 2013-07-10 17:33:00 2013-07-10 17:33:00
# 19 2013-07-10 17:34:00 2013-07-10 17:34:00
#
#                                  User_ID  \
# ...
