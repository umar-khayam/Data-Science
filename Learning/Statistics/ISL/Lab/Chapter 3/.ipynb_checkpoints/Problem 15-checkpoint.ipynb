# %% [markdown]
# # 15. This problem involves the Boston data set, which we saw in the lab for this chapter.
#
# We will now try to predict per capita crime rate using the other variables in this data set. In other words, per capita crime rate is the response, and the other variables are the predictors.

# %%
import pandas as pd
import numpy as np

from ISLP import load_data

import statsmodels.api as sm
from ISLP.models import summarize

import matplotlib.pyplot as plt
import seaborn as sns

# %%
boston = load_data("Boston") 
boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %% [markdown]
# ## (a) For each predictor, fit a simple linear regression model to predict the response.
#
# Describe your results. In which of the models is there a statistically significant association between the predictor and the response? Create some plots to back up your assertions.

# %%
boston['intercept'] = np.ones(boston.shape[0])

# %%
model_a = []
for col in boston.columns:
    if col not in ['crim','intercept']:
        model_a.append(sm.OLS(boston['crim'], boston[['intercept',col]]).fit())
        
        
for i in model_a:
    
    print(summarize(i))
    
    print('\n')
# Out:
#              coef  std err       t  P>|t|
# intercept  4.4537    0.417  10.675    0.0
# zn        -0.0739    0.016  -4.594    0.0
#
#
#              coef  std err      t  P>|t|
# intercept -2.0637    0.667 -3.093  0.002
# indus      0.5098    0.051  9.991  0.000
#
#
#              coef  std err      t  P>|t|
# intercept  3.7444    0.396  9.453  0.000
# chas      -1.8928    1.506 -1.257  0.209
#
#
#               coef  std err       t  P>|t|
# intercept -13.7199    1.699  -8.073    0.0
# nox        31.2485    2.999  10.419    0.0
#
#
#               coef  std err      t  P>|t|
# intercept  20.4818    3.364  6.088    0.0
# rm         -2.6841    0.532 -5.045    0.0
#
#
#              coef  std err      t  P>|t|
# intercept -3.7779    0.944 -4.002    0.0
# age        0.1078    0.013  8.463    0.0
#
#
#              coef  std err       t  P>|t|
# intercept  9.4993    0.730  13.006    0.0
# dis       -1.5509    0.168  -9.213    0.0
#
#
#              coef  std err       t  P>|t|
# intercept -2.2872    0.443  -5.157    0.0
# rad        0.6179    0.034  17.998    0.0
#
#
#              coef  std err       t  P>|t|
# intercept -8.5284    0.816 -10.454    0.0
# tax        0.0297    0.002  16.099    0.0
#
#
#               coef  std err      t  P>|t|
# intercept -17.6469    3.147 -5.607    0.0
# ptratio     1.1520    0.169  6.801    0.0
#
#
#              coef  std err       t  P>|t|
# intercept -3.3305    0.694  -4.801    0.0
# lstat      0.5488    0.048  11.491    0.0
#
#
#               coef  std err       t  P>|t|
# intercept  11.7965    0.934  12.628    0.0
# medv       -0.3632    0.038  -9.460    0.0

# %% [markdown]
# All the predictors has statistically significant association with response, except the predictor **chas**.

# %%
pair_plot_fig = sns.pairplot(data=boston, 
                             y_vars=['crim'], 
                             x_vars=['zn', 'indus', 'chas', 'nox', 'rm'],
                             height=3)

# Set the size of the figure
pair_plot_fig.fig.set_size_inches(10, 4)

# %%
pair_plot_fig = sns.pairplot(data=boston, 
                             y_vars=['crim'], 
                             x_vars=['rm', 'age', 'dis', 'rad', 'tax'],
                             height=3)

# Set the size of the figure
pair_plot_fig.fig.set_size_inches(10, 4)

# %%
pair_plot_fig = sns.pairplot(data=boston, 
                             y_vars=['crim'], 
                             x_vars=['ptratio', 'lstat', 'medv'],
                             height=3)

# Set the size of the figure
pair_plot_fig.fig.set_size_inches(10, 4)

# %% [markdown]
# ## (b) Fit a multiple regression model to predict the response using all of the predictors.
#
# Describe your results. For which predictors can we reject the null hypothesis H0 : βj = 0?

# %%
cols = ['intercept'] + [col for col in boston.columns if col != 'intercept' and col !='crim']

# %%
X = boston[cols]
y = boston['crim']

# %%
model_b = sm.OLS(y, X).fit()
summarize(model_b)
# Out:
#               coef  std err      t  P>|t|
# intercept  13.7784    7.082  1.946  0.052
# zn          0.0457    0.019  2.433  0.015
# indus      -0.0584    0.084 -0.698  0.486
# chas       -0.8254    1.183 -0.697  0.486
# nox        -9.9576    5.290 -1.882  0.060
# rm          0.6289    0.607  1.036  0.301
# age        -0.0008    0.018 -0.047  0.962
# dis        -1.0122    0.282 -3.584  0.000
# rad         0.6125    0.088  6.997  0.000
# tax        -0.0038    0.005 -0.730  0.466
# ptratio    -0.3041    0.186 -1.632  0.103
# lstat       0.1388    0.076  1.833  0.067
# medv       -0.2201    0.060 -3.678  0.000

# %% [markdown]
# We can reject the null hypothesis for below predictors
# 1. zn
# 2. dis
# 3. rad
# 4. medv

# %% [markdown]
# ## (c) How do your results from (a) compare to your results from (b)?
#
# Create a plot displaying the univariate regression coefficients from (a) on the x-axis, and the multiple regression coefficients from (b) on the y-axis. That is, each predictor is displayed as a single point in the plot. Its coefficient in a simple linear regression model is shown on the x-axis, and its coefficient estimate in the multiple linear regression model is shown on the y-axis.

# %%
model_a_coef = []

# get the model a coefficient and append them in a list one by one
for i in model_a:
    model_a_coef.append(i.params[1])


# get the coefficient of model b
model_b_coef = model_b.params

# drop the element intercept and its value
model_b_coef = model_b_coef.drop('intercept')

#converting pandas series into dataframe
model_df = model_b_coef.to_frame(name='model b')
model_df['model a'] = model_a_coef

model_df
# Out:
#           model b    model a
# zn       0.045710  -0.073935
# indus   -0.058350   0.509776
# chas    -0.825378  -1.892777
# nox     -9.957587  31.248531
# rm       0.628911  -2.684051
# age     -0.000848   0.107786
# dis     -1.012247  -1.550902
# rad      0.612465   0.617911
# tax     -0.003776   0.029742
# ptratio -0.304073   1.151983
# lstat    0.138801   0.548805
# medv    -0.220056  -0.363160

# %%
plt.scatter(model_df['model a'], model_df['model b'])
plt.xlabel('model a cofficients') 
plt.ylabel('model b cofficients')
plt.title('Relationship between the cofficients of model a and b')
plt.show()

# %% [markdown]
# ## (d) Is there evidence of non-linear association between any of the predictors and the response?
#
# To answer this question, for each predictor X, fit a model of the form
# Y = β0 + β1X1 + β2X2 ^ 2 + β3X3 ^ 3 + ε.

# %%
boston = boston.drop('intercept', axis=1)

X = boston.drop('crim', axis=1)

# %%
y = boston['crim']

# %%
X.shape[1]
# Out:
# 12

# %%
for col in X.columns:
    for i in range(1,4):
        X[col+'_deg_'+str(i)] = X[col]**i
    size += 1
X.head()
# Out:
#      zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  ...  \
# 0  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3  ...
# 1   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8  ...
# 2   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8  ...
# 3   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7  ...
# 4   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7  ...
#
#    tax_deg_3  ptratio_deg_1  ptratio_deg_2  ptratio_deg_3  lstat_deg_1  \
# 0   25934336           15.3         234.09       3581.577         4.98
# 1   14172488           17.8         316.84       5639.752         9.14
# 2   14172488           17.8         316.84       5639.752         4.03
# 3   10941048           18.7         349.69       6539.203         2.94
# 4   10941048           18.7         349.69       6539.203         5.33
#
#    lstat_deg_2  lstat_deg_3  medv_deg_1  medv_deg_2  medv_deg_3
# 0      24.8004   123.505992        24.0      576.00   13824.000
# 1      83.5396   763.551944        21.6      466.56   10077.696
# 2      16.2409    65.450827        34.7     1204.09   41781.923
# 3       8.6436    25.412184        33.4     1115.56   37259.704
# 4      28.4089   151.419437        36.2     1310.44   47437.928
#
# [5 rows x 48 columns]

# %%
cols = ['intercept'] + [col for col in boston.columns if col != 'intercept' and col !='crim']

# %%
X['intercept'] = 1

# %%
model_b = sm.OLS(y, X).fit()
summarize(model_b)
# Out:
#                        coef       std err      t  P>|t|
# zn            -2.430000e-02  4.700000e-02 -0.521  0.603
# indus          6.950000e-02  3.500000e-01  0.199  0.843
# chas           8.630000e-02  2.700000e-01  0.320  0.749
# nox            2.417376e+02  1.151090e+02  2.100  0.036
# rm            -1.895200e+00  1.289400e+01 -0.147  0.883
# age            3.910000e-02  7.200000e-02  0.540  0.589
# dis           -5.017600e+00  1.062000e+00 -4.727  0.000
# rad            6.235000e-01  5.230000e-01  1.191  0.234
# tax            2.360000e-02  5.700000e-02  0.415  0.678
# ptratio        9.259000e-01  1.175400e+01  0.079  0.937
# lstat          6.266000e-01  2.570000e-01  2.438  0.015
# medv          -2.311900e+00  2.610000e-01 -8.860  0.000
# zn_deg_1      -2.430000e-02  4.700000e-02 -0.521  0.603
# zn_deg_2       1.500000e-03  3.000000e-03  0.511  0.609
# zn_deg_3      -9.627000e-06  2.390000e-05 -0.403  0.687
# indus_deg_1    6.960000e-02  3.500000e-01  0.199  0.842
# indus_deg_2    4.000000e-03  6.300000e-02  0.064  0.949
# indus_deg_3   -4.000000e-04  2.000000e-03 -0.230  0.819
# chas_deg_1     8.630000e-02  2.700000e-01  0.320  0.749
# chas_deg_2     8.630000e-02  2.700000e-01  0.320  0.749
# chas_deg_3     8.630000e-02  2.700000e-01  0.320  0.749
# nox_deg_1      2.417376e+02  1.151090e+02  2.100  0.036
# nox_deg_2     -8.100858e+02  3.744850e+02 -2.163  0.031
# nox_deg_3      4.204626e+02  1.978120e+02  2.126  0.034
# rm_deg_1      -1.895200e+00  1.289400e+01 -0.147  0.883
# rm_deg_2       2.580000e-01  4.142000e+00  0.062  0.950
# rm_deg_3       7.400000e-03  2.180000e-01  0.034  0.973
# age_deg_1      3.910000e-02  7.200000e-02  0.540  0.589
# age_deg_2     -2.800000e-03  3.000000e-03 -0.981  0.327
# age_deg_3      2.092000e-05  1.700000e-05  1.232  0.218
# dis_deg_1     -5.017600e+00  1.062000e+00 -4.727  0.000
# dis_deg_2      1.564500e+00  3.790000e-01  4.123  0.000
# dis_deg_3     -7.440000e-02  2.100000e-02 -3.585  0.000
# rad_deg_1      6.235000e-01  5.230000e-01  1.191  0.234
# rad_deg_2     -1.713000e-01  1.510000e-01 -1.136  0.257
# rad_deg_3      6.200000e-03  5.000000e-03  1.305  0.193
# tax_deg_1      2.360000e-02  5.700000e-02  0.415  0.678
# tax_deg_2     -1.000000e-04  0.000000e+00 -0.450  0.653
# tax_deg_3      7.657000e-08  2.120000e-07  0.362  0.718
# ptratio_deg_1  9.259000e-01  1.175400e+01  0.079  0.937
# ptratio_deg_2 -6.460000e-02  1.373000e+00 -0.047  0.963
# ptratio_deg_3  1.000000e-04  2.600000e-02  0.005  0.996
# lstat_deg_1    6.266000e-01  2.570000e-01  2.438  0.015
# lstat_deg_2   -9.250000e-02  3.000000e-02 -3.079  0.002
# lstat_deg_3    1.600000e-03  1.000000e-03  3.095  0.002
# medv_deg_1    -2.311900e+00  2.610000e-01 -8.860  0.000
# medv_deg_2     1.456000e-01  2.000000e-02  7.143  0.000
# medv_deg_3    -1.500000e-03  0.000000e+00 -6.223  0.000
# intercept     -3.902650e+01  1.448320e+02 -0.269  0.788

# %%
model_d = []
for col in boston.columns:
    if col not in ['crim','intercept']:
        model_d.append(sm.OLS(boston['crim'], X[['intercept',col]]).fit())
        
        
for i in model_d:
    
    print(summarize(i))
    
    print('\n')
# Out:
#              coef  std err       t  P>|t|
# intercept  4.4537    0.417  10.675    0.0
# zn        -0.0739    0.016  -4.594    0.0
#
#
#              coef  std err      t  P>|t|
# intercept -2.0637    0.667 -3.093  0.002
# indus      0.5098    0.051  9.991  0.000
#
#
#              coef  std err      t  P>|t|
# intercept  3.7444    0.396  9.453  0.000
# chas      -1.8928    1.506 -1.257  0.209
#
#
#               coef  std err       t  P>|t|
# intercept -13.7199    1.699  -8.073    0.0
# nox        31.2485    2.999  10.419    0.0
#
#
#               coef  std err      t  P>|t|
# intercept  20.4818    3.364  6.088    0.0
# rm         -2.6841    0.532 -5.045    0.0
#
#
#              coef  std err      t  P>|t|
# intercept -3.7779    0.944 -4.002    0.0
# age        0.1078    0.013  8.463    0.0
#
#
#              coef  std err       t  P>|t|
# intercept  9.4993    0.730  13.006    0.0
# dis       -1.5509    0.168  -9.213    0.0
#
#
#              coef  std err       t  P>|t|
# intercept -2.2872    0.443  -5.157    0.0
# rad        0.6179    0.034  17.998    0.0
#
#
#              coef  std err       t  P>|t|
# intercept -8.5284    0.816 -10.454    0.0
# tax        0.0297    0.002  16.099    0.0
#
#
#               coef  std err      t  P>|t|
# intercept -17.6469    3.147 -5.607    0.0
# ptratio     1.1520    0.169  6.801    0.0
#
#
#              coef  std err       t  P>|t|
# intercept -3.3305    0.694  -4.801    0.0
# lstat      0.5488    0.048  11.491    0.0
#
#
#               coef  std err       t  P>|t|
# intercept  11.7965    0.934  12.628    0.0
# medv       -0.3632    0.038  -9.460    0.0
