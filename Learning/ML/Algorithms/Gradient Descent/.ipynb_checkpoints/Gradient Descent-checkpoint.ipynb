# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
X,y = make_regression(n_samples=4, n_features=1, n_informative=1, n_targets=1, noise=80, random_state=13)

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)

# %%
#first finding value of slope and intercept with OLS method
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([78.35063668])

# %%
reg.intercept_
# Out:
# 26.15963284313262

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red')

# %% [markdown]
# ### Calculating b, and m is constant

# %%
# Lets apply gradient descent assuming slope is contant m = 78.35
# And starting value of b = 0  
y_pred = ((78.35 * X ) + 0).reshape(4)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS')
plt.plot(X,y_pred,color='green',label='b = 0')
plt.legend()
plt.show()

# %%
#Iteration 1
m = 78.35
b = 0
 
loss_slop = -2 * np.sum(y - m*X.ravel() - b)
loss_slop
# Out:
# -209.27763408209216

# %%
lr = 0.1

step_size = loss_slop*lr
step_size
# Out:
# -20.927763408209216

# %%
b = b - step_size
b
# Out:
# 20.927763408209216

# %%
y_pred_1 = ((78.35 * X ) + b).reshape(4)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS')
plt.plot(X,y_pred,color='green',label='b = 0')
plt.plot(X,y_pred_1,color='blue',label='b = {}'.format(b))
plt.legend()
plt.show()

# %%
#Iteration 2
loss_slop = -2 * np.sum(y - m*X.ravel() - b)
loss_slop
# Out:
# -41.85552681641843

# %%
step_size = loss_slop*lr
step_size
# Out:
# -4.185552681641844

# %%
b = b - step_size

# %%
y_pred_2 = ((78.35 * X ) + b).reshape(4)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS')
plt.plot(X,y_pred,color='green',label='b = 0')
plt.plot(X,y_pred_1,color='blue',label='b = {}'.format(b))
plt.plot(X,y_pred_2,color='orange',label='b = {}'.format(b))
plt.legend()
plt.show()

# %%
#Iteration 3
loss_slop = -2 * np.sum(y - m*X.ravel() - b)
loss_slop
# Out:
# -8.371105363283675

# %%
step_size = loss_slop*lr
step_size
# Out:
# -0.8371105363283675

# %%
y_pred_3 = ((78.35 * X ) + b).reshape(4)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS')
plt.plot(X,y_pred,color='green',label='b = 0')
plt.plot(X,y_pred_1,color='blue',label='b = {}'.format(b))
plt.plot(X,y_pred_2,color='orange',label='b = {}'.format(b))
plt.plot(X,y_pred_3,color='black',label='b = {}'.format(b))
plt.legend()
plt.show()

# %%
# in loop
m = 78.35
b = -10
lr = 0.1
epochs = 100

for i in range(epochs):
    loss_slope = -2 * np.sum(y - m*X.ravel() - b)
    b = b - (lr * loss_slope)
    
    y_pred = m * X + b
    
    plt.plot(X,y_pred)

plt.scatter(X,y)

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=20)

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [92.65051408]
# 0.1656030828564834

# %%
m = 92.65051408

# %%
class GDRegressor:
    
    def __init__(self,learning_rate,epochs):
        self.m =  92.65051408
        self.b = 120
        self.lr = learning_rate
        self.epochs = epochs
        
    def fit(self,X,y):
        for i in range(self.epochs):
            loss_slope = -2 * np.sum(y - self.m*X.ravel() - self.b)
            self.b -= (self.lr * loss_slope)
            print(self.b)
        print(self.b)

# %%
gd = GDRegressor(0.001,100)

# %%
gd.fit(X,y)
# Out:
# 96.03312061672715
# 76.85961711010887
# 61.52081430481425
# 49.24977206057855
# 39.43293826518999
# 31.579471228879143
# 25.296697599830466
# 20.270478696591525
# 16.24950357400037
# 13.032723475927448
# 10.459299397469108
# 8.400560134702436
# 6.753568724489099
# 5.43597559631843
# 4.381901093781894
# 3.538641491752666
# 2.864033810129283
# 2.3243476648305768
# 1.8925987485916118
# 1.54719961560044
# 1.2708803092075023
# 1.0498248640931525
# 0.8729805080016723
# 0.731505023128488
# 0.6183246352299405
# 0.527780324911103
# 0.45534487665603274
# 0.39739651805197657
# 0.35103783116873166
# 0.3139508816621357
# 0.2842813220568588
# 0.26054567437263754
# 0.24155715622526058
# 0.22636634170735875
# 0.21421369009303728
# 0.20449156880158023
# 0.1967138717684147
# 0.19049171414188204
# 0.1855139880406559
# 0.18153180715967512
# 0.1783460624548906
# 0.17579746669106275
# 0.1737585900800005
# 0.1721274887911508
# 0.17082260776007116
# 0.16977870293520722
# 0.16894357907531626
# ...

# %% [markdown]
# ### Calculating m and b both

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import cross_val_score

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=20,random_state=13)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [28.12597332]
# -2.2710144261783825

# %%
from sklearn.metrics import r2_score
r2_score(y_test,lr.predict(X_test))
# Out:
# 0.6345158782661012

# %%
np.mean(cross_val_score(lr,X,y,scoring='r2',cv=10))
# Out:
# 0.6375011587464419

# %%
class GDRegressor:
    
    def __init__(self,learning_rate,epochs):
        self.m = 0
        self.b = 1
        self.lr = learning_rate
        self.epochs = epochs
        
    def fit(self,X,y):
        for i in range(self.epochs):
            loss_slope_b = -2 * np.sum(y - self.m*X.ravel() - self.b)
            loss_slope_m = -2 * np.sum((y - self.m*X.ravel() - self.b)* X.ravel())
            
            self.b = self.b - (self.lr * loss_slope_b)
            self.m = self.m - (self.lr * loss_slope_m)
        print(self.m, self.b)
        
    def predict(self,X):
        return self.m * X + self.b

# %%
gd = GDRegressor(0.001, 100)

# %%
gd.fit(X_train,y_train)
# Out:
# 28.125970431111753 -2.2710128638511544

# %%
r2_score(y_test,gd.predict(X_test))
# Out:
# 0.6345158901290594
