# %%
import pandas as pd
import re

# %%
def preprocess(data):
    # Define the pattern to split the date and message parts
    pattern = r'\[\d{1,2}/\d{1,2}/\d{4},\s\d{1,2}:\d{2}:\d{2}\s[apAP][mM]\]'
    messages = re.split(pattern, data)[1:]
    dates = re.findall(pattern, data)

    # Create a DataFrame
    df = pd.DataFrame({'user_message': messages, 'message_date': dates})

    # Convert message_date to datetime and format it correctly
    df['message_date'] = df['message_date'].str.replace('[', '').str.replace(']', '').str.replace('‎', '')
    df['message_date'] = pd.to_datetime(df['message_date'], format='%d/%m/%Y, %I:%M:%S %p')

    # Extract user and message
    df[['user', 'message']] = df['user_message'].str.extract(r'([^:]+):\s?(.*)', expand=True)

    # Drop the original user_message column
    df.drop(columns=['user_message'], inplace=True)

    # Rename columns for clarity
    df.rename(columns={'message_date': 'date'}, inplace=True)

    # Extract date components
    df['only_date'] = df['date'].dt.date
    df['year'] = df['date'].dt.year
    df['month_num'] = df['date'].dt.month
    df['month'] = df['date'].dt.month_name()
    df['day'] = df['date'].dt.day
    df['day_name'] = df['date'].dt.day_name()
    df['hour'] = df['date'].dt.hour
    df['minute'] = df['date'].dt.minute

    # Define the period of the day
    period = []
    for hour in df['hour']:
        if hour == 23:
            period.append(str(hour) + "-" + str('00'))
        elif hour == 0:
            period.append(str('00') + "-" + str(hour + 1))
        else:
            period.append(str(hour) + "-" + str(hour + 1))
    df['period'] = period

    return df

# %%
with open('_chat.txt', 'r') as file:
    # Read the contents of the file
    chat_contents = file.read()
df = preprocess(chat_contents)
df.head()
# Out:
# /var/folders/xq/6knst1p10zx6vcf03b4zyf300000gn/T/ipykernel_82548/3382911504.py:11: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['message_date'] = df['message_date'].str.replace('[', '').str.replace(']', '').str.replace('‎', '')
#                  date                        user  \
# 0 2020-01-29 19:04:19   Peaky THF Blinders ✨🖤❤️‍🔥
# 1 2020-01-29 19:04:19   Salman Bhai
# 2 2020-01-29 19:04:19   Peaky THF Blinders ✨🖤❤️‍🔥
# 3 2021-11-26 00:06:08   Fahad Kasha jahaz
# 4 2021-11-26 00:06:26   Umar Khayam
#
#                                                                                                                      message  \
# 0  ‎Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them.
# 1  ‎Salman Bhai created this group
# 2  ‎You were added
# 3  insha'Allah❤️ best of luck bro !
# 4  آئیں گے انشاللہ
#
#     only_date  year  month_num     month  day   day_name  hour  minute period
# 0  2020-01-29  2020  1          January   29   Wednesday  19    4       19-20
# 1  2020-01-29  2020  1          January   29   Wednesday  19    4       19-20
# 2  2020-01-29  2020  1          January   29   Wednesday  19    4       19-20
# 3  2021-11-26  2021  11         November  26   Friday     0     6       00-1
# 4  2021-11-26  2021  11         November  26   Friday     0     6       00-1

# %%
pd.set_option('display.max_rows', False)  # Set it to None to display all rows
pd.set_option('display.max_colwidth', False)  # Set it to None to display full width of the column
df['message'].value_counts()
# Out:
# ‎image omitted                                             1885
# ‎audio omitted                                             1325
# ‎video omitted                                             532
# Ok                                                         192
# ok                                                         165
# ‎sticker omitted                                           138
# 🤣                                                          113
# 😂                                                          111
# ?                                                          107
# han                                                        67
# Ameen                                                      63
# Insha Allah                                                61
#                                                            ..
# Khana lasani pe kha lety hein, chach interchange ke pas    1
# 5:30 asar ki namaz ky bad                                  1
# 23514  2023-11-03  2023  11         November  3    Friday     10    56
# 23515  2023-11-03  2023  11         November  3    Friday     10    57
# 23517  2023-11-03  2023  11         November  3    Friday     10    58
# 23519  2023-11-03  2023  11         November  3    Friday     21    18
# 23520  2023-11-03  2023  11         November  3    Friday     21    19
# 23522  2023-11-03  2023  11         November  3    Friday     21    19
# 23523  2023-11-03  2023  11         November  3    Friday     21    41
# 23524  2023-11-04  2023  11         November  4    Saturday   8     56
#
#       period
# 0      19-20
# 1      19-20
# 2      19-20
# 3      00-1
# 4      00-1
# 5      00-1
# 7      00-1
# 8      6-7
# 9      9-10
# ...     ...
# 23512  10-11
# 23514  10-11
# 23515  10-11
# 23517  10-11
# 23519  21-22
# 23520  21-22
# 23522  21-22
# 23523  21-22
# 23524  8-9
#
# [18505 rows x 12 columns]

# %%
def most_common_words(selected_user,df):

    f = open('stop_hinglish.txt','r')
    stop_words = f.read()

    if selected_user != 'Overall':
        df = df[df['user'] == selected_user]

    pattern = r'image|video|audio|document omitted'

    # Use the `str.contains` method to apply the regex pattern, setting `na=False` to treat NaNs as False
    mask = df['message'].str.contains(pattern, na=False)
    temp = df[~mask]

    words = []

    for message in temp['message']:
        for word in message.lower().split():
            if word not in stop_words:
                words.append(word)
    print(words)
    most_common_df = pd.DataFrame(Counter(words).most_common(20))
    return most_common_df

# %%
most_common_words('Overall', df)
# Out:
# ['\u200emessages', 'calls', 'end-to-end', 'encrypted.', 'chat,', 'whatsapp,', 'listen', 'them.', '\u200esalman', 'created', 'group', '\u200eyou', 'added', "insha'allah❤️", 'luck', '!', 'آئیں', 'گے', 'انشاللہ', "insha'allah❤️", 'ھاھاھاھاھاھا', 'کل', 'پروجیکٹر', 'پر', 'لگا', 'لو', '😂', 'umar', 'miss', 'sayy', 'nbr', 'pouch', 'mry', 'fhdi', 'اوکے', 'hi!', 'find', 'attached', 'sample', 'data.', 'participant', 'list', 'products', '(give_ids)', 'receive', '(get_ids).', 'participant', 'product', 'receive', 'return.', 'implement', 'exchange', 'algorithm', 'python.', 'problem', 'discrete', 'optimization', 'mathematical', 'terms.', 'face', 'problem:', 'set', 'participants', 'exchange', 'experiment.', 'participant', 'listed', 'object', 'offers', 'object', 'desires.', 'participants', 'countertrade', 'objects', 'possession', 'objects', 'desire.', 'trade', 'object', 'exchange', 'object.', 'goal', 'find', 'trading', 'cycles', 'satisfy', 'maximum', 'amount', 'participants.', 'cycles', 'constrained', 'length', 'failure', 'trading', 'participant', 'affect', 'participants.', 'mathematical', 'terminology,', 'problem', 'maximum', 'cost', 'circulation', 'problem.', 'here,', 'objects', 'nodes', 'directed', 'graph', '=', '(v,', 'a)', 'participants', 'directed', 'arcs.', 'arc/participant', '(u,', ')', 'represents', 'desired', 'object', 'offered', 'object', 'respective', 'participant.', 'with-', 'length', 'constraint', 'deal', 'resilience,', 'maximum', 'cost', 'circulation', 'problem,', 'arc', 'capacity', 'cost', 'one.', 'solved', 'polynomial', 'time,', 'see,', 'e.g.', '[1].', 'package', 'potentially', 'solution:', 'https://developers.google.com/optimization/flow/mincostflow', 'dataset.', 'project', 'objective', 'goal', 'implement', 'software', 'tool', 'efficiently', 'finds', 'resilient', 'cycles', 'described', 'graph.', 'software', 'find', 'optimal', 'solution', 'dataset', 'provided', 'company.', 'sari', 'baj', '😒', '🍌🍌🍌', 'poster', 'banain', 'lagain', '😂', 'اب', 'کوئی', 'نہیں', 'بنتا', 'tujy', 'mny', 'bacha', 'bhai.', 'bki', 'pics', 'documents', 'send', 'hala', '!', 'ہاں', 'بس', 'احسان', 'نا', 'جتا', 'گٹ', 'کے', 'بے', 'جل', 'یار', 'اگلا', 'لا', 'میرے', 'اٹھا', 'تب', 'بھیجوں', 'گا', 'putar', 'tuda', 'dasna', 'chup', 'baj', '!', 'کے', 'دس', 'سے', 'نہیں', 'بھیجتا', 'akhiri', 'wari', 'ankhna', 'baj', 'day', '😏', 'اسکے', 'بعد', 'کیا', 'کرے', 'گا؟', 'baj', 'hay😂😂😂', 'ھاھاھاھا', 'بھیجتا', 'ہوں', '❤️❤️', '💫😂', 'baj', 'naaaa', 'heic', 'format', 'supprt', 'heic', 'اُف', '🔥🔥', 'یار', 'نہیں', 'ہیں', 'کیسے', 'بھیجو', 'ہاں', 'جی', 'fadi', 'yra', 'notes', 'bejo', 'brothers', 'mask', 'pehny', 'rkho', 'sab,', 'ghr', 'walo', 'ehtiyaat', 'krwao', 'یس', 'خیریت؟', 'kaam', 'tyz', 'کسکا؟', 'yha', 'bukhar', 'heavy', 'sy', 'allah', 'pyary', 'gaey', 'corona', 'نہیں', 'یارا', 'bajta', 'jni', 'tori', 'uta', 'allah', 'pak', 'khir', 'kry', '!', 'allah', 'khair', 'kary', 'yr', 'ihtiyat', 'aysa', 'https://www.facebook.com/groups/sarcasticsocietylol/permalink/953218485275307/?sfnsn=scwspwa', 'کاش', 'تم', 'ادھر', 'ہوتے،', 'آپکا', 'مساج', 'ہم', 'کرتے۔', 'مناسب', 'ریٹ', 'کے', 'ساتھ۔', '🤣', '🤣', '😂', 'check', 'status', '🤣', '😂😂', 'keft', 'group', '🤣', 'massage', 'ھاھاھاھا', 'ہاں', 'maam', 'email?', 'mid', 'paper', 'lab', 'aqsa@cuiatk.edu.pk', 'quiz', 'topics', 'recursive', 'trees', ',', 'master', 'theorem,', 'insertion', 'sort', 'quiz', 'yhi', 'topics', 'hn', 'allhmdulilah', 'mash', 'allah', 'mubarik', '💔', 'fahad', 'ukasha', 'koie', 'insh', 'allah', 'alhumdulliha', '!', 'mashallah', 'allah', 'shukar', "insha'allah", "insha'allah", 'allah', 'khir', 'kry', 'pershan', 'ukkasha', 'pakistan', 'dykhi', 'hmari', 'govt', 'kysy', 'lati', 'yrr', '!', 'allah', 'khir', 'kry', 'change', 'kriyo', 'mery', 'sy', 'dobara', 'banti', 'soft', 'banani', 'hy!', 'pta', 'hala', 'hala', '😅', 'krlein', 'ahana', 'kl', 'lana', 'jul', 'bsdk', 'nikl', 'oky', '😂😂😂😂', '@923487961357', '3400', 'hn', '😄', 'thora', 'frq', 'thora', 'check', 'yr', '😂', 'ukasha', 'hazro', 'mah', 'dukan', 'mah', 'tittli', 'labbi', 'filhal', ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 most_common_words('Overall', df)
#
# Cell In[47], line 22, in most_common_words(selected_user, df)
#      20             words.append(word)
#      21 print(words)
# ---> 22 most_common_df = pd.DataFrame(Counter(words).most_common(20))
#      23 return most_common_df
#
# NameError: name 'Counter' is not defined
